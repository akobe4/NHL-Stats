# %%
import pandas as pd 
import requests
import os
import json
import numpy as np

# %% [markdown]
# ## Playoff Series Carousel

# %%
data = []

response =  requests.get("https://api-web.nhle.com/v1/playoff-series/carousel/20252026/")
data.append(response.json())

# %%
#from IPython.display import JSON
#JSON(data)
