# %%
import pandas as pd 
import requests
import os
import json
import numpy as np
from json import JSONDecodeError

# %%
#import player info file for player id's
skater_id_data = pd.read_csv(r'C:\Users\Alex\Documents\NHL-Stats\2025-2026\regular_season\Data\csv\player_info_skaters.csv')

# %%
#create list of playerid's 
skater_id_list = skater_id_data['player_id'].tolist()

# %% [markdown]
# # Skater Data

# %% [markdown]
# ### Skater Detail

# %% [markdown]
# ###### Retrieve player rankings for NHL Edge data, Includes top shot speed, skating speed, distance skated, shot on goal summary/details, zone time percentages.

# %%
#### need to figure out 


#create url's for each player id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-detail/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skater_details = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        skater_details.append(response.json())
    except JSONDecodeError:
        pass

# %%
#Store the JSON data in a file
#with open("skater_details.json", "w") as file:
#    json.dump(skater_details, file)

# %%
nylander = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-detail/8477939/20252026/2")
nylander.append(response.json())

# %%
#from IPython.display import JSON
#JSON(skater_details)

# %% [markdown]
# ## ----------------------------------------------------------------------------------------------

# %% [markdown]
# ### Skater Landing

# %% [markdown]
# ###### Retrieve leading player for NHL Edge data, Includes top shot speed, skating speed, distance skated, high danger SOG, zone time percentages.

# %%
skater_landing = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-landing/20252026/2")
skater_landing.append(response.json())

# %%
#from IPython.display import JSON
#JSON(skater_landing)

# %%
#Store the JSON data in a file
#with open("skater_landing.json", "w") as file:
#    json.dump(skater_landing, file)

# %% [markdown]
# ### Skater Comparison

# %% [markdown]
# ###### Retrieve NHL Edge data for the specified player, Includes skating distance and speed data, shot location and speed data, zone time details and zone starts.

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-comparison/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skater_comparison = []

for i in range(len(all_url)):
    response = requests.get(all_url[i])
    skater_comparison.append(response.json())

# %%
#from IPython.display import JSON
#JSON(skater_comparison)

# %%
#Store the JSON data in a file
#with open("skater_comparison.json", "w") as file:
#    json.dump(skater_comparison, file)

# %% [markdown]
# ### Skater Distance - Top 10

# %% [markdown]
# ###### Retrieve top 10 skaters in skating distance based on the provided filters - all positions, all situations, total distance

# %%
skater_distance_top_10 = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-distance-top-10/all/all/total/20252026/2")
skater_distance_top_10.append(response.json())

# %%
#Store the JSON data in a file
#with open("skater_distance_top_10.json", "w") as file:
#    json.dump(skater_distance_top_10, file)

# %% [markdown]
# ### Skater Skating Distance - Detail

# %% [markdown]
# ###### Skater skating distance by all locations and positions

# %%
## need to figure out 

#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-skating-distance-detail/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skating_distance = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        skating_distance.append(response.json())
    except JSONDecodeError:
        pass

# %%
#Store the JSON data in a file
#with open("skating_distance_detail.json", "w") as file:
#    json.dump(skating_distance, file)

# %% [markdown]
# ## Skater Speed - Top 10

# %% [markdown]
# ###### Retrieve 10 fastest skaters based on the provided filters - all postions, max skating speed

# %%
skater_speed_top_10 = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-speed-top-10/all/max/20252026/2")
skater_speed_top_10.append(response.json())

# %%
#Store the JSON data in a file
#with open("skater_speed_top_10.json", "w") as file:
#    json.dump(skater_speed_top_10, file)

# %% [markdown]
# ### Skater Skating Speed - Detail

# %% [markdown]
# ###### Retrieve top 10 skating speeds for the provided player. Also provides max skating speed, bursts over 22mph, bursts from 20 to 22mph and bursts from 18 to 20mph.

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-skating-speed-detail/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skating_speed_detail = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        skating_speed_detail.append(response.json())
    except JSONDecodeError:
        pass

# %%
#Store the JSON data in a file
#with open("skating_speed_detail.json", "w") as file:
#    json.dump(skating_speed_detail, file)

# %% [markdown]
# ### Skater Zone Time - Top 10

# %% [markdown]
# ###### Retrieve 10 fastest skaters based on the provided filters - all positions, all situations - off/def/neu

# %%
skater_zone_time_top_10_off = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-zone-time-top-10/all/all/offensive/20252026/2")
skater_zone_time_top_10_off.append(response.json())

# %%
skater_zone_time_top_10_neu = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-zone-time-top-10/all/all/neutral/20252026/2")
skater_zone_time_top_10_neu.append(response.json())

# %%
skater_zone_time_top_10_def = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-zone-time-top-10/all/all/defensive/20252026/2")
skater_zone_time_top_10_def.append(response.json())

# %%
#Store the JSON data in a file
#with open("skater_zone_time_top_10_def.json", "w") as file:
#    json.dump(skater_zone_time_top_10_def, file)

# %% [markdown]
# ### Skater Zone Time - Detail

# %% [markdown]
# ###### Zone time details by situation (All Situations/Even Strength/Power Play/Penalty Kill). Includes zone starts.

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-zone-time/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skater_zone_time_detail = []

for i in range(len(all_url)):
    response = requests.get(all_url[i])
    skater_zone_time_detail.append(response.json())

# %%
#from IPython.display import JSON
#JSON(skater_zone_time_detail)

# %%
#Store the JSON data in a file
#with open("skater_zone_time_detail.json", "w") as file:
#    json.dump(skater_zone_time_detail, file)

# %% [markdown]
# ### Skater Shot Speed - Top 10

# %% [markdown]
# ###### Retrieve 10 players with the fastest shot based on the provided filters - all, max

# %%
skater_shot_speed_top_10 = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-shot-speed-top-10/all/max/20252026/2")
skater_shot_speed_top_10.append(response.json())

# %%
#Store the JSON data in a file
#with open("skater_shot_speed_top_10.json", "w") as file:
#    json.dump(skater_shot_speed_top_10, file)

# %% [markdown]
# ### Skater Shot Speed - Detail

# %% [markdown]
# ###### Provides the 10 hardest shots for a specified player. Includes top shot speed, average shot speed, shot attempts in the following groups: 100+, 90-100, 80-90, 70-80.

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-shot-speed-detail/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skater_shot_speed_detail = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        skater_shot_speed_detail.append(response.json())
    except JSONDecodeError:
        pass

# %%
#Store the JSON data in a file
#with open("skater_shot_speed_detail.json", "w") as file:
#    json.dump(skater_shot_speed_detail, file)

# %% [markdown]
# ### Skater Shot Locations - Top 10

# %% [markdown]
# ###### Description: Presumably top 10 skaters based on the specified filters. -TODO
# ###### Do not have all the parameters to run correctly

# %%
skater_shot_location_top_10 = []

response =  requests.get("https://api-web.nhle.com/v1/edge/skater-shot-location-top-10/F/{category}/{sort-by}/20252026/2")
skater_shot_location_top_10.append(response.json())

# %%
#Store the JSON data in a file
#with open("skater_shot_location_top_10.json", "w") as file:
#    json.dump(skater_shot_location_top_10, file)

# %% [markdown]
# ### Skater Shot Location - Detail

# %% [markdown]
# ###### Provides information on shot location

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/edge/skater-shot-location-detail/'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
skater_shot_location_detail = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        skater_shot_location_detail.append(response.json())
    except JSONDecodeError:
        pass

# %%
#Store the JSON data in a file
#with open("skater_shot_location_detail.json", "w") as file:
#    json.dump(skater_shot_location_detail, file)

# %% [markdown]
# ### CAT - Skater Detail

# %% [markdown]
# ######  Provides information on top shot speed, skating speed/distance, shots on goal summary/details and zone time details.

# %%
#create url's for each team id
all_url = []

for i in range(len(skater_id_list)):
    skater_id = skater_id_list[i]
    skater_id_url = 'https://api-web.nhle.com/v1/cat/edge/skater-detail'+str(skater_id)+'/20252026/2'
    all_url.append(skater_id_url)

# %%
cat_skater_detail = []

for i in range(len(all_url)):
    try:
        response = requests.get(all_url[i])
        cat_skater_detail.append(response.json())
    except JSONDecodeError:
        pass
# Out:
# ---------------------------------------------------------------------------
# SSLEOFError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:741, in HTTPSConnection.connect(self)
#     739 server_hostname_rm_dot = server_hostname.rstrip(".")
# --> 741 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
# ...

# %%
nylander = []

response =  requests.get("https://api-web.nhle.com/v1/cat/edge/skater-detail/8477939/20252026/2")
nylander.append(response.json())

# %%
#from IPython.display import JSON
#JSON(nylander)
