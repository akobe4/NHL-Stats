# %%
import pandas as pd 
import requests
import os
import json
import numpy as np

# %%
# Opening JSON file
f = open(r'C:\Users\Alex\Documents\NHL-Stats\2025-2026\Data\boxscore_all.json')
boxscore_data = json.load(f)

# %%
#from IPython.display import JSON
#JSON(boxscore_data)
