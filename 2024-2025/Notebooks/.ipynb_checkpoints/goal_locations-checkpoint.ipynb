# %% [markdown]
# ## Goal Locations for the League's Top 5 Goal Scorers
#
# ##### 1.Leon Draisaitl - 52
# ##### 2.William Nylander - 45
# ##### T-3.Alex Ovechkin - 44
# ##### T-3. Tage Thompson - 44
# ##### 5. David Pastrnak - 43

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from matplotlib import image 
from matplotlib import pyplot as plt

# %%
'C:/Users/Alex/Documents/NHL-Stats/2024-2025/SQL/Query-Results/goals_top_5_scorers.csv'

# %%
#import the data
#index col = [0] makes sures another index column is not added

game_data = pd.read_csv(r'C:/Users/Alex/Documents/NHL-Stats/2024-2025/SQL/Query-Results/goals_top_5_scorers.csv', index_col = [0])

# %%
game_data.head()
# Out:
#             game_period  event_id time_in_period time_remaining  \
# game_id
# 2024020229            2       605           7:42          12:18
# 2024020229            3       800           2:09          17:51
# 2024021171            3       984           9:11          10:49
# 2024020605            2       714          15:08           4:52
# 2024020579            1       304          12:04           7:56
#
#             situation_code home_def_code  type_code event_name  \
# game_id
# 2024020229            1551         right        505       goal
# 2024020229            1541          left        505       goal
# 2024021171            1551         right        505       goal
# 2024020605            1451          left        505       goal
# 2024020579            1551         right        505       goal
#
#             event_owner_team_id zone_code  ...  goalie_in_id  score_player_id  \
# game_id                                    ...
# ...

# %%
#plotting coordinates on scatterplot 
sns.scatterplot(data = game_data, x = 'x_coord', y = 'y_coord')
# Out:
# <Axes: xlabel='x_coord', ylabel='y_coord'>
